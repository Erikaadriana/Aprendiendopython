# %%
#reconoceremos el dataframe y hacemos graficas
import pandas as pd
df_poblacion=pd.read_csv("/content/population_total (1).csv", encoding="ISO-8859-1")

# %%
df_poblacion.head(9)
# Out:
#   country    year    population
# 0   China  2020.0  1.439324e+09
# 1   China  2019.0  1.433784e+09
# 2   China  2018.0  1.427648e+09
# 3   China  2017.0  1.421022e+09
# 4   China  2016.0  1.414049e+09
# 5   China  2015.0  1.406848e+09
# 6   China  2010.0  1.368811e+09
# 7   China  2005.0  1.330776e+09
# 8   China  2000.0  1.290551e+09

# %%
#lo primero que vaos a hacer es eliminar los vacios ,con el metodo dropna
df_poblacion.dropna()
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4178 rows x 3 columns]

# %%
#sobreescribo el dataframe
df_poblacion.dropna(inplace=True)

# %%
#primero pivoteammos pra que la visualizacion sea mas amigable
df_poblacion.pivot(index="year",columns="country",values="population")
# Out:
# country  Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# year
# 1955.0     8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960.0     8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965.0     9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970.0    11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975.0    12689160.0  2411732.0  16607707.0         30052.0  30705.0
# 1980.0    13356511.0  2682690.0  19221665.0         32646.0  36067.0
# 1985.0    11938208.0  2969672.0  22431502.0         39519.0  44600.0
# 1990.0    12412308.0  3286073.0  25758869.0         47347.0  54509.0
# 1995.0    18110657.0  3112936.0  28757785.0         53161.0  63850.0
# 2000.0    20779953.0  3129243.0  31042235.0         57821.0  65390.0
# 2005.0    25654277.0  3086810.0  33149724.0         59562.0  78867.0
# 2010.0    29185507.0  2948023.0  35977455.0         56079.0  84449.0
# ...

# %%
#cree unnuevo dataframe
df_poblacion_pivot=df_poblacion.pivot(index="year",columns="country",values="population")
df_poblacion_pivot
# Out:
# country  Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# year
# 1955.0     8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960.0     8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965.0     9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970.0    11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975.0    12689160.0  2411732.0  16607707.0         30052.0  30705.0
# 1980.0    13356511.0  2682690.0  19221665.0         32646.0  36067.0
# 1985.0    11938208.0  2969672.0  22431502.0         39519.0  44600.0
# 1990.0    12412308.0  3286073.0  25758869.0         47347.0  54509.0
# 1995.0    18110657.0  3112936.0  28757785.0         53161.0  63850.0
# 2000.0    20779953.0  3129243.0  31042235.0         57821.0  65390.0
# 2005.0    25654277.0  3086810.0  33149724.0         59562.0  78867.0
# 2010.0    29185507.0  2948023.0  35977455.0         56079.0  84449.0
# ...

# %%
#hora vamos a llamar algunos paises para no trabajr con todo el dataframe
df_poblacion_pivot[["Colombia","Argentina","China","Indonesia"]]
# Out:
# country    Colombia   Argentina         China    Indonesia
# year
# 1955.0   13775000.0  18789418.0  6.122416e+08   77273425.0
# 1960.0   16057724.0  20481779.0  6.604081e+08   87751068.0
# 1965.0   18725245.0  22159650.0  7.242190e+08  100267062.0
# 1970.0   21480065.0  23880561.0  8.276014e+08  114793178.0
# 1975.0   24065507.0  25865776.0  9.262409e+08  130680727.0
# 1980.0   26900506.0  27896528.0  1.000089e+09  147447836.0
# 1985.0   29951201.0  30216279.0  1.075589e+09  164982451.0
# 1990.0   33102575.0  32618651.0  1.176884e+09  181413402.0
# 1995.0   36421438.0  34828170.0  1.240921e+09  196934260.0
# 2000.0   39629968.0  36870787.0  1.290551e+09  211513823.0
# 2005.0   42647723.0  38892931.0  1.330776e+09  226289470.0
# 2010.0   45222700.0  40895752.0  1.368811e+09  241834215.0
# 2015.0   47520667.0  43075416.0  1.406848e+09  258383256.0
# 2016.0   48175052.0  43508460.0  1.414049e+09  261556381.0
# 2017.0   48909839.0  43937140.0  1.421022e+09  264650963.0
# ...

# %%
#sobreescribo
df_poblacion_pivot=df_poblacion_pivot[["Colombia","Argentina","China","Indonesia"]]

# %%
#vamos hacer una grafica de lineas
#usaremos el argumento Kind
#el metodo para graficar es plot
#podemos personalizar la grafica con otros argumentos
#x label me sirve para darle nombre al eje X
#y label me sirve para darle nombre al eje Y
#title me sirve para darle un titulo a la grafica
#figzize me sirve para modificar el tamaño del lienzo
#hay muchos mas
df_poblacion_pivot.plot(kind="line",xlabel="Año",ylabel="Poblacion",
                        title="Poblacion 1955-2020", figsize=(10,5))
# Out:
# <Axes: title={'center': 'Poblacion 1955-2020'}, xlabel='Año', ylabel='Poblacion'>
