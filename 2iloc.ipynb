# %%
#a doferencia de loc. iloc se usa con los indices de cada elemento, estao evita que devamos conocer todos los elementos
import pandas as pd
df_jugadores=pd.read_csv("/content/players_20 (1).csv")
df_jugadores.head(3)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# ...

# %%
df_jugadores=df_jugadores.set_index("short_name")
df_jugadores.head(3)
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
#
#                    height_cm  weight_kg nationality                 club  \
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# ...

# %%
#cortamos solo las columnas
de_jugadores=df_jugadores[["player_url","long_name","age","dob","height_cm","weight_kg","nationality","club"]]
df_jugadores.head(3)
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
#
#                    height_cm  weight_kg nationality                 club  \
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# ...

# %%
df_jugadores.iloc[1]
# Out:
# sofifa_id                                                 20801
# player_url    https://sofifa.com/player/20801/c-ronaldo-dos-...
# long_name                   Cristiano Ronaldo dos Santos Aveiro
# age                                                          34
# dob                                                  1985-02-05
#                                     ...
# lb                                                         61+3
# lcb                                                        53+3
# cb                                                         53+3
# rcb                                                        53+3
# rb                                                         61+3
# Name: Cristiano Ronaldo, Length: 103, dtype: object

# %%
#para trraer dos datos es decir una fila y una columna uso
df_jugadores.iloc[1,5]
# Out:
# 187

# %%
#para optener elclucb de neymar
df_jugadores.iloc[2,8]
# Out:
# 'Paris Saint-Germain'

# %%
#para traer el nombre ocmpleto de todos los jugadores lo haria de la siguiente manera
df_jugadores.iloc[: , 1]
# Out:
# short_name
# L. Messi             https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo    https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr            https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak             https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard            https://sofifa.com/player/183277/eden-hazard/2...
#                                            ...
# M. Braithwaite       https://sofifa.com/player/193290/martin-braith...
# P. Bargfrede         https://sofifa.com/player/193311/philipp-bargf...
# M. Destro            https://sofifa.com/player/193338/mattia-destro...
# H. Behrens           https://sofifa.com/player/193425/hanno-behrens...
# X. Chavalerin        https://sofifa.com/player/193683/xavier-chaval...
# Name: player_url, Length: 2019, dtype: object

# %%
df_jugadores.iloc[: , 7]
# Out:
# short_name
# L. Messi             Argentina
# Cristiano Ronaldo     Portugal
# Neymar Jr               Brazil
# J. Oblak              Slovenia
# E. Hazard              Belgium
#                        ...
# M. Braithwaite         Denmark
# P. Bargfrede           Germany
# M. Destro                Italy
# H. Behrens             Germany
# X. Chavalerin           France
# Name: nationality, Length: 2019, dtype: object

# %%
df_jugadores.iloc[3 , : ]
# Out:
# sofifa_id                                                200389
# player_url    https://sofifa.com/player/200389/jan-oblak/20/...
# long_name                                             Jan Oblak
# age                                                          26
# dob                                                  1993-01-07
#                                     ...
# lb                                                          NaN
# lcb                                                         NaN
# cb                                                          NaN
# rcb                                                         NaN
# rb                                                          NaN
# Name: J. Oblak, Length: 103, dtype: object

# %%
df_jugadores.iloc[-1 , : ]
# Out:
# sofifa_id                                                193683
# player_url    https://sofifa.com/player/193683/xavier-chaval...
# long_name                                     Xavier Chavalerin
# age                                                          28
# dob                                                  1991-03-07
#                                     ...
# lb                                                          NaN
# lcb                                                         NaN
# cb                                                          NaN
# rcb                                                         NaN
# rb                                                          NaN
# Name: X. Chavalerin, Length: 103, dtype: object

# %%
#ibtener los datos de varias personas
df_jugadores.iloc[[1,2,3] , : ]
# Out:
#                    sofifa_id  \
# short_name
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
#
#                                                           player_url  \
# short_name
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
#
#                                              long_name  age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
#
#                    height_cm  weight_kg nationality                 club  \
# short_name
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# ...

# %%
df_jugadores.iloc[4,[6,3]]
# Out:
# weight_kg    74
# age          28
# Name: E. Hazard, dtype: object

# %%
#trar peso y estatura dee leo mesi y cristiano
df_jugadores.iloc[[1,4],[6,3]]
# Out:
#                    weight_kg  age
# short_name
# Cristiano Ronaldo         83   34
# E. Hazard                 74   28

# %%
#vamos a traer solo los datso de low hast el final
jugadores=[0,1]
df_jugadores.iloc[jugadores,3:]
# Out:
#                    age         dob  height_cm  weight_kg nationality  \
# short_name
# L. Messi            32  1987-06-24        170         72   Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
#
#                            club  overall  potential  value_eur  wage_eur  ...  \
# short_name                                                                ...
# L. Messi           FC Barcelona       94         94   95500000    565000  ...
# Cristiano Ronaldo      Juventus       93         93   58500000    405000  ...
#
#                     lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# short_name
# L. Messi           68+2  66+2  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# Cristiano Ronaldo  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
#
# [2 rows x 100 columns]

# %%
#como obtenemoslos jugadores por top 10
df_jugadores.iloc[0:10, :]
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# K. De Bruyne          192985
# M. ter Stegen         192448
# V. van Dijk           203376
# L. Modrić             177003
# M. Salah              209331
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# K. De Bruyne       https://sofifa.com/player/192985/kevin-de-bruy...
# M. ter Stegen      https://sofifa.com/player/192448/marc-andre-te...
# ...

# %%
#ahora a combinaar condiciones usando el ilox
#vamomos a filtrar jugadores que sean mas alto a 180 y que sean argentinos
df_jugadores.iloc[list((df_jugadores["height_cm"]>180) & (df_jugadores["nationality"]=="Argentina")), :]
# Out:
#               sofifa_id                                         player_url  \
# short_name
# M. Icardi        201399  https://sofifa.com/player/201399/mauro-icardi/...
# G. Higuaín       167664  https://sofifa.com/player/167664/gonzalo-higua...
# E. Garay         170481  https://sofifa.com/player/170481/ezequiel-gara...
# N. Otamendi      192366  https://sofifa.com/player/192366/nicolas-otame...
# G. Rulli         215316  https://sofifa.com/player/215316/geronimo-rull...
# ...                 ...                                                ...
# W. Caballero     139062  https://sofifa.com/player/139062/willy-caballe...
# M. Barovero      142721  https://sofifa.com/player/142721/marcelo-barov...
# M. Barbosa       142959  https://sofifa.com/player/142959/mariano-barbo...
# G. Cabral        165536  https://sofifa.com/player/165536/gustavo-cabra...
# C. Álvarez       188938  https://sofifa.com/player/188938/cristian-alva...
#
# ...
